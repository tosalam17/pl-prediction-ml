# %%
from prem_model_training import Footy_Predictor
foot = Footy_Predictor()
# Out:
# /Users/tsalami/Desktop/Prem Predict/prem_model_training.py:92: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df = df.apply(pd.to_numeric, errors="ignore")
# /Users/tsalami/Desktop/Prem Predict/prem_model_training.py:92: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df = df.apply(pd.to_numeric, errors="ignore")
# /Users/tsalami/Desktop/Prem Predict/prem_model_training.py:92: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df = df.apply(pd.to_numeric, errors="ignore")
# ...

# %%
foot.train_model()

result = foot.predict_game("Liverpool", "Newcastle United", date = "2026-01-31", year = "2025")
print(result)
# Out:
# [0.32105348 0.23895882 0.4399877 ]
# Accuracy: 0.4666666666666667
# Log loss: 1.033892604201821
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.52      0.59      0.55        22
#            1       0.33      0.04      0.07        26
#            2       0.45      0.78      0.57        27
#
#     accuracy                           0.47        75
#    macro avg       0.43      0.47      0.40        75
# weighted avg       0.43      0.47      0.39        75
#
#
# Confusion matrix:
#  [[13  1  8]
#  [ 7  1 18]
#  [ 5  1 21]]
# {'prediction': 'Liverpool wins🥳', 'Chance of Liverpool winning': '48.64%', 'Chance of a draw': '23.84%', 'Chance of Newcastle United winning': '27.52%'}

# %%
from pprint import pprint
print("Predictions for todays PL Game:")
pprint(result)
# Out:
# Predictions for todays PL Game:
# {'Chance of Liverpool winning': '48.64%',
#  'Chance of Newcastle United winning': '27.52%',
#  'Chance of a draw': '23.84%',
#  'prediction': 'Liverpool wins🥳'}
